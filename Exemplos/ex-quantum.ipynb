# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '0.16.4'

# %%
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.16.4',
#  'qiskit-aer': '0.7.6',
#  'qiskit-ignis': '0.5.2',
#  'qiskit-ibmq-provider': '0.12.1',
#  'qiskit-aqua': '0.8.2',
#  'qiskit': '0.24.0'}

# %%
from qiskit import IBMQ

# %%
IBMQ.save_account('ADD_SUA_KEY_SIMULADOR')

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>
